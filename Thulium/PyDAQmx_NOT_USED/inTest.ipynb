# %%
# %pylab inline
import PyDAQmx as dq
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
help(dq.Task)
# Out:
# Help on class Task in module PyDAQmx.Task:
#
# class Task(CallbackParent)
#  |  Method resolution order:
#  |      Task
#  |      CallbackParent
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  AddGlobalChansToTask(self, channelNames)
#  |      T.AddGlobalChansToTask(channelNames) -> error.
#  |
#  |  CfgAnlgEdgeRefTrig(self, triggerSource, triggerSlope, triggerLevel, pretriggerSamples)
#  |      T.CfgAnlgEdgeRefTrig(triggerSource, triggerSlope, triggerLevel, pretriggerSamples) -> error.
#  |
#  |  CfgAnlgEdgeStartTrig(self, triggerSource, triggerSlope, triggerLevel)
#  |      T.CfgAnlgEdgeStartTrig(triggerSource, triggerSlope, triggerLevel) -> error.
#  |
#  |  CfgAnlgWindowRefTrig(self, triggerSource, triggerWhen, windowTop, windowBottom, pretriggerSamples)
#  |      T.CfgAnlgWindowRefTrig(triggerSource, triggerWhen, windowTop, windowBottom, pretriggerSamples) -> error.
#  |
# ...
